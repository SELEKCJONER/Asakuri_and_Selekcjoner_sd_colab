# %% [markdown]
# <HTML>
# <b><font size="5">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;This is an Automatic1111 colab notebook made by:</center></font></b>
# <table>
# <tr>
# <td><font size="4"><b><center>SELEKCJONER<br><img src="https://cdn.discordapp.com/avatars/838059648875495425/4161326bab6853d4f16cec3cf165a723.webp?size=100"></center></b></font></td>
# <td><font size="4">Created Notebook Logic & Laid the Foundation of new setup UI</font></td>
# </tr>
# <tr>
# <td><font size="4"><b><center>Asakuri<br><img src="https://cdn.discordapp.com/avatars/188903265931362304/a_f0abb082a40c17e65193620a8620b823.gif?size=100"></center></b></font></td>
# <td><font size="4">Revamped new setup UI and is a Co-author of the Notebook</font></td>
# </tr>
# <tr>
# <td><font size="4"><b><center>Casanova<br><img src="https://cdn.discordapp.com/avatars/316484463037251588/1eaeecd7a2b9cae337210c7927dabc16.webp?size=100"></center></b></font></td>
# <td><font size="4">Provided links to 24 models</font></td>
# </tr>
# </table>
# </HTML>

# %%
#@title Run this to open setup and start SD { display-mode: "form" }

#@markdown <font color="#94cfff"> Just run this cell to open setup inerface <br><br>  To restart SD click run cell button once <br> To get back to setup spam it and select restart

import random
import os
from IPython.display import display, HTML
from IPython.display import Javascript
import subprocess
subprocess.call(["pip", "install","jupyter_ui_poll"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
subprocess.call(["apt-get", "install","aria2"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
from jupyter_ui_poll import ui_events
import ipywidgets as widgets
import time
from ipywidgets import HTML, VBox, HBox
from IPython.display import clear_output

exit_setup = False
Nuri_embeddings = True
Nuri_extensions = True

model_list = [["Pixai real v3 (realistic)","Film grain v2 (realistic)","Magicmix v5 (realistic)","Chilloutmix v2 (realistic)","Lyriel (semi realistic)","Dreamshaper (semi realistic)","Rev animated (2.5D)","Fentexi (2.5D)","Yabalmix (2.5D)","Camilia mix (anime)","Yabalmix v3 (anime)","Manmaru mix (cartoon)","Counterfeit v3 (anime)","Kyumix v1 (anime)","Ruvimix v2 (anime)","Replicant v3 (anime)","Meinamix v10 (anime)","Moyu (anime)","Meinahentai v3 (anime)","Meinapastal v5 (anime)","anylora (anime)","Model-EX","MiracleMix","disneypixar","disneypixar_Type A","disneypixar_type B","IdentityCrisis","VinteProtogenMix","Perfect World","Remedy","CompassionMix","BokoMix","DonutHoleMix","Project KR4X - 2.5D / AaYMix","Pastel-Mix [Stylized Anime Model]","MeinaMix","Anything V5","AbyssOrangeMix3","DarkRevPikas","OS-Ambrosia","Epic Mix - V3","MechaMix","Ageless","Mymix","TMND-Mix","dosmix","Corneros 7th Heaven Mix","Identity Disorder","Epic Mix","MIXPROV4","Nyan mix","viewer-mix_v1.7","MoonTea","ToonYou","CoffeeMix","Sardonyx Redux","Ametrine REDUX","Dark Sushi Mix","Galena Redux","SCH Excelsior","Hassaku Hentai","SakushiMix Hentai","RealCartoon3D","exquisiteDetails_v10","4cheemsblend_v10","Break domain anime","Yabalmix v5","Sleeplessmix v1","DarkrevPikas v3","ModelEX v2.5","AbyssOrange2xAnyv4","end_v10","envyoverdrivexl_v10DS","nixesmix_v10","toonyouJP_alpha1","blazingDrive_v03","camelliamix_v3","darkSushiMixMix_colorful","darkSushi25D25D_v30","darkSushiMixMix_darkerPruned","duchaitenThiccboi_v10","kizukiAnimeHentai_animeHentaiV3","nabimix_v2","orangeGalenyxMerge_v11","renaigadeFantasy_v10","ultraInfinityAnime_v2Yamime","yogirimix_v10","maturemalemix","MeichiLight_Mix","GhostMix","Lawlas's Yiffymix 2.0 (furry model)","YiffyMix 3.2 (furry model)","Coconut furry mix (furry model)","Pirsus Comics style - Soft fantasy"],["https://huggingface.co/WolfAether21/chilled_re-generic_v3/resolve/main/chilledReGenericV3_v10.safetensors","https://huggingface.co/doctord98/stable/resolve/main/filmgrainv2.safetensors","https://huggingface.co/sinkinai/majicMIX-realistic-v5/resolve/main/majicmixRealistic_v5.safetensors","https://huggingface.co/swl-models/chilloutmix-ni/resolve/main/chilloutmix-Ni.safetensors","https://huggingface.co/serta21/lyriel_v16/resolve/main/lyriel_v16.safetensors","https://huggingface.co/Lykon/DreamShaper/resolve/main/DreamShaper_7_pruned.safetensors","https://huggingface.co/hanafuusen2001/ReVAnimated/resolve/main/revAnimated_v122.safetensors","https://huggingface.co/john1786/V08_V08/resolve/main/V08_V08.safetensors","https://huggingface.co/doctord98/stable/resolve/main/yabalmix25.safetensors","https://huggingface.co/Mods13/CamelliaMix/resolve/main/CamelliaMix_2.5D_V1.safetensors","https://huggingface.co/doctord98/stable/resolve/main/yabalmix.safetensors","https://huggingface.co/doctord98/stable/resolve/main/manmarumix.safetensors","https://huggingface.co/gsdf/Counterfeit-V3.0/resolve/main/Counterfeit-V3.0.safetensors","https://huggingface.co/RuviKyu/Ruvi_Official_Models/resolve/main/KyuMix_v1.0.safetensors","https://huggingface.co/RuviKyu/Ruvi_Official_Models/resolve/main/RuviMix_v2.0.safetensors","https://huggingface.co/gsdf/Replicant-V3.0/resolve/main/Replicant-V3.0_fp32.safetensors","https://huggingface.co/Meina/MeinaMix/resolve/main/Meina%20V10%20-%20baked%20VAE.safetensors","https://huggingface.co/CasanovaSan/moyu/resolve/main/moyu.safetensors","https://huggingface.co/Meina/MeinaHentai/resolve/main/meinaHentai%20V3%20-%20baked%20VAE.safetensors","https://huggingface.co/Meina/MeinaPastel/resolve/main/MeinaPastelV5%20-%20Baked%20VAE.safetensors","https://civitai.com/api/download/models/95489","https://civitai.com/api/download/models/36396?type=Model&format=SafeTensor&size=full&fp=fp16","https://civitai.com/api/download/models/108548","https://civitai.com/api/download/models/106561","https://civitai.com/api/download/models/69832","https://civitai.com/api/download/models/80409","https://civitai.com/api/download/models/94798","https://civitai.com/api/download/models/23690","https://civitai.com/api/download/models/77276","https://civitai.com/api/download/models/92584","https://civitai.com/api/download/models/92179","https://civitai.com/api/download/models/93713","https://civitai.com/api/download/models/83231","https://civitai.com/api/download/models/79841","https://civitai.com/api/download/models/6297","https://civitai.com/api/download/models/80511","https://civitai.com/api/download/models/33672?type=Model&format=PickleTensor&size=full&fp=fp16","https://civitai.com/api/download/models/17233","https://civitai.com/api/download/models/66374","https://civitai.com/api/download/models/82000","https://civitai.com/api/download/models/79279","https://civitai.com/api/download/models/74096","https://civitai.com/api/download/models/74004","https://civitai.com/api/download/models/75982","https://civitai.com/api/download/models/93612","https://huggingface.co/nolanaatama/dsmx/resolve/main/dsmx.safetensors","https://civitai.com/api/download/models/6878","https://civitai.com/api/download/models/61088","https://civitai.com/api/download/models/34229","https://huggingface.co/nolanaatama/mxprv4/resolve/main/mxprv4.safetensors","https://civitai.com/api/download/models/18151","https://civitai.com/api/download/models/25845","https://huggingface.co/swl-models/MoonTea-v2/resolve/main/MoonTea_V2.0.safetensors","https://civitai.com/api/download/models/58693","https://civitai.com/api/download/models/53475","https://civitai.com/api/download/models/105566?type=Model&format=SafeTensor&size=pruned&fp=fp16","https://huggingface.co/CasanovaSan/GalenaRedux/resolve/main/ametrineREDUX_v20.safetensors","https://huggingface.co/CasanovaSan/GalenaRedux/resolve/main/darkSushiMixMix_brighterPruned.safetensors","https://huggingface.co/CasanovaSan/GalenaRedux/resolve/main/galenaREDUX_v20.safetensors","https://huggingface.co/CasanovaSan/GalenaRedux/resolve/main/schExcelsior_v20.safetensors","https://huggingface.co/CasanovaSan/GalenaRedux/resolve/main/hassakuHentaiModel_v12.safetensors","https://huggingface.co/CasanovaSan/GalenaRedux/resolve/main/sakushimixHentai_sakushiV20.safetensors","https://civitai.com/api/download/models/118590?type=Model&format=SafeTensor&size=full&fp=fp16","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/exquisiteDetails_v10.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/4cheemsblend_v10.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/breakdomainanime_A0440.safetensors","https://huggingface.co/CasanovaSan/models/resolve/main/yabalMix_v5.safetensors","https://huggingface.co/CasanovaSan/models/resolve/main/sleeplessmix_v10.safetensors","https://huggingface.co/CasanovaSan/models/resolve/main/darkrevpikas_v30Pruned.safetensors","https://huggingface.co/CasanovaSan/models/resolve/main/modelEX_v25.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/AbyssOrange2xAnyV4_HateMix_nsfw_ClipFix.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/end_v10.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/envyoverdrivexl_v10DS.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/nixesmix_v10.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/toonyouJP_alpha1.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/blazingDrive_v03.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/camelliamix_v3.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/darkSushiMixMix_colorful.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/darkSushi25D25D_v30.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/darkSushiMixMix_darkerPruned.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/duchaitenThiccboi_v10.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/kizukiAnimeHentai_animeHentaiV3.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/nabimix_v2.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/orangeGalenyxMerge_v11.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/renaigadeFantasy_v10.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/ultraInfinityAnime_v2Yamime.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/yogirimix_v10.safetensors","https://civitai.com/api/download/models/75441?type=Model&format=SafeTensor&size=full&fp=fp16","https://civitai.com/api/download/models/147809?type=Model&format=SafeTensor&size=pruned&fp=fp16","https://civitai.com/api/download/models/76907?type=Model&format=SafeTensor&size=pruned&fp=fp16","https://civitai.com/api/download/models/15460?type=Model&format=SafeTensor&size=full&fp=fp16","https://civitai.com/api/download/models/127237?type=Model&format=SafeTensor&size=full&fp=fp32","https://civitai.com/api/download/models/128393?type=Model&format=SafeTensor&size=full&fp=fp32","https://civitai.com/api/download/models/89541?type=Model&format=SafeTensor&size=full&fp=fp16"]]
mapped_model_list = list(zip(model_list[0], model_list[1]))

# Define custom CSS for toggle button states
custom_css = HTML("""
<style>
    /*cell output these values are used instead of default shit from above*/
    html[theme=dark] {
        background: url(https://ik.imagekit.io/gmethsnvl/99049667_p0_Mt0h-4UhU.png) !important;
        background-size: cover !important;
        background-position: center !important;
        background-repeat: no-repeat !important;
		    display: flex !important;
		    justify-content: center !important;
		    align-items: center !important;
        --colab-primary-surface-color: transparent !important; /* Darker output cell bg */
        --colab-secondary-surface-color: #5e0000 !important; /* Darker output cell dropdown and continue button */
        --jp-ui-font-color1: #a0a0a0 !important; /* Darker every button font color */
        --jp-widgets-color: #a0a0a0 !important; /* Darker non-button text color */
        --jp-ui-font-color1: white !important;
        --jp-layout-color2: #1d5e00 !important;

        --jp-widgets-input-background-color: var(--jp-layout-color1) !important;
        --jp-widgets-label-color: var(--jp-widgets-color) !important;
        --jp-widgets-readout-color: var(--jp-widgets-color) !important;
        --jp-widgets-font-size: var(--jp-ui-font-size1) !important;
        --jp-widgets-margin: 2px !important;
        --jp-widgets-inline-height: max-content !important;
        --jp-widgets-inline-width: 300px !important;
        --jp-widgets-inline-width-short: calc(var(--jp-widgets-inline-width) / 2 - var(--jp-widgets-margin)) !important;
        --jp-widgets-inline-width-tiny: calc(var(--jp-widgets-inline-width-short) / 2 - var(--jp-widgets-margin)) !important;
        --jp-widgets-inline-margin: 4px !important;
        --jp-widgets-inline-label-width: 80px !important;
        --jp-widgets-border-width: var(--jp-border-width) !important;
        --jp-widgets-vertical-height: 200px !important;
        --jp-widgets-horizontal-tab-height: 24px !important;
        --jp-widgets-horizontal-tab-width: 144px !important;
        --jp-widgets-horizontal-tab-top-border: 2px !important;
        --jp-widgets-progress-thickness: 20px !important;
        --jp-widgets-container-padding: 15px !important;
        --jp-widgets-input-padding: 4px !important;
        --jp-widgets-radio-item-height-adjustment: 8px !important;
        --jp-widgets-radio-item-height: calc(var(--jp-widgets-inline-height) - var(--jp-widgets-radio-item-height-adjustment)) !important;
        --jp-widgets-slider-track-thickness: 4px !important;
        --jp-widgets-slider-border-width: var(--jp-widgets-border-width) !important;
        --jp-widgets-slider-handle-size: 16px !important;
        --jp-widgets-slider-handle-border-color: var(--jp-border-color1) !important;
        --jp-widgets-slider-handle-background-color: var(--jp-layout-color1) !important;
        --jp-widgets-slider-active-handle-color: var(--jp-brand-color1) !important;
        --jp-widgets-menu-item-height: 24px !important;
        --jp-widgets-input-color: var(--jp-ui-font-color1) !important;
        --jp-widgets-input-border-color: var(--jp-border-color1) !important;
        --jp-widgets-input-focus-border-color: var(--jp-brand-color2) !important;
        --jp-widgets-input-border-width: var(--jp-widgets-border-width) !important;
        --jp-widgets-disabled-opacity: 0.6 !important;
        --md-shadow-key-umbra-opacity: 0.2 !important;
        --md-shadow-key-penumbra-opacity: 0.14 !important;
        --md-shadow-ambient-shadow-opacity: 0.12 !important;
    }


    button
    {
        border: 1px solid #d4d4d4;
        border-radius: .5rem;
		    color: #ab4390;
		    padding: .5rem 1rem !important;
    }

    .widget-toggle-button
    {
        background-color: #dc262699;
        transition: background .25s linear;
    }

    .widget-toggle-button .widget-label
    {
        text-align: left;
        width: 100%;
    }

    .widget-toggle-button.jupyter-button:active,.jupyter-button.mod-active
    {
        background-color: #16a34a99 !important;

    }

    .widget-html > .widget-html-content,.widget-htmlmath > .widget-html-content
    {
        /* backdrop-filter: blur(10px) !important; */
        color: var(--jp-ui-font-color1);
    }

    @keyframes selectGradient {
        0% {
            background: #ab438f99;
        }
        25% {
            background: #d35a7499;
        }
        50% {
            background: #af4b6999;
        }
        75% {
            background: #d35a7499;
        }
        100% {
            background: #ab438f99;
        }
    }

    @keyframes optionGradient {
        0% {
            background: #ab438f;
        }
        25% {
            background: #d35a74;
        }
        50% {
            background: #af4b69;
        }
        75% {
            background: #d35a74;
        }
        100% {
            background: #ab438f;
        }
    }

	@keyframes glow {
		0%,
		100% {
			box-shadow: 0 0 3px #ab438f, 0 0 5px #ab438f, 0 0 8px #ab438f, 0 0 10px #ab438f;
		}
		25%, 75% {
			box-shadow: 0 0 6px #d35a74BF, 0 0 5px #d35a74BF, 0 0 8px #d35a74BF, 0 0 10px #d35a74BF;
		}
		50% {
			box-shadow: 0 0 10px #ab438f80, 0 0 20px #ab438f80, 0 0 30px #ab438f80, 0 0 40px #ab438f80;
		}
	}

	#header-container {
		margin: 0;
		padding: 0.5rem 1rem 1rem 1rem;
		text-align: center;
		display: flex;
		flex-direction: column;
		gap: 0.25rem;
	}

	#header-container h2 {
		margin: 0;
		padding: 0;
		font-size: xx-large;
	}

	#header-container span {
		font-size: small;
		color: gray;
	}

	#select-label {
		height: 100%;
		color: #af4b69;

		display: flex;
		justify-content: center;
		align-items: center;
	}

	.widget-dropdown:has(select) {
		height: max-content;
		display: flex;

		gap: 0.5rem;
		justify-content: center;
		align-items: center;
	}

    .widget-dropdown > select {
        background: #ab438f99;
        backdrop-filter: blur(4px) saturate(1.5);

        animation: selectGradient 3s linear infinite;
        height: max-content !important;

        padding: 0.5rem 1rem;

        border: 1px solid white;
        border-radius: 0.5rem;
    }

	/* For dropdown menu rollout formatting */
    option {
        background: #ab438f;
        animation: optionGradient 3s linear infinite;
        border-radius: 0.5rem;
    }

	#output-area {
		min-height: 600px;
		display: flex !important;
        flex-direction: column;

		justify-content: center;
		align-items: center;
        gap: 0.5rem;
	}

	#output-body {
		height: max-content;

		display: flex !important;
        flex-direction: column;

		justify-content: center;
		align-items: center;
        gap: 0.5rem;

		padding: 1rem !important;
		background: #241431b3;
		backdrop-filter: blur(12px) saturate(1.5);;

		border: 4px solid rgb(171 67 144);
		border-radius: 0.5rem;

		animation: glow 2s ease-in-out infinite;
	}

	/* Error output */
	div.error.output-id-5.output-error {
		padding: 0.5rem 1rem;
	}

	div.error.output-id-5.output-error::before {
		content: "Error";

		display: block;
		text-align: center;

		color: #e2717e;
		font-size: x-large;
		font-weight: 700;
	}
</style>
""")
#css for sd output
running_css = HTML("""
	<style>
  div.stream, div.execute_result, div.output_text, div.output_text pre
  {
    display: inline;
    white-space: pre-line;
    overflow: hidden;
    text-overflow: ellipsis;
    transform: scale(0.9);
    overflow-y: auto;

  }
	#output-body
  {
		max-width: 600px !important;
    max-height: 500px;
    gap: unset !important;
	}
  div.stream::-webkit-scrollbar
  {
    display: none;
  }

   </style>
""")
# loading stuff
felix = "https://files.catbox.moe/ah0ool.webp"
emilia = "https://files.catbox.moe/a3pzd6.webp"
rem = "https://files.catbox.moe/iok7nh.webp"
ram = "https://files.catbox.moe/052ul1.webp"

bouncing_img_url_list = [felix,emilia,rem,ram]
bouncing_img_url = random.choices(bouncing_img_url_list, weights=[1,1,1,1])[0]
audio_file = "https://files.catbox.moe/5pz0yq.mp3"

Html_start = f"""
<style>
  #output-body
  {{
		height: max-content !important;
	}}
  	#output-body
  {{
		height: max-content;
	}}
  .widget-html > .widget-html-content, .widget-htmlmath > .widget-html-content
  {{
  width: 900px !important;
  }}

	@keyframes bounce {{
		0% {{
        	margin-left: 0%;
        }}
		50% {{
			margin-left: 55%;
		}}
		100% {{
			margin-left: 0%;
		}}
	}}

	@keyframes spin {{
		from {{
			transform: rotate(0deg);
		}}
		to {{
			transform: rotate(360deg);
		}}
	}}

	#animate-spin {{
		animation: spin 1s linear infinite;

		width: 16px;
		height: 16px;
	}}

	#bouncing_image {{
		position: relative;
		width: 400px;
		animation: bounce 13s linear infinite;

		border-radius: 0.5rem;
	}}

	#elevator_music {{
		display: none;
	}}

	#progress-container {{
		position: relative;

		width: 100%;
		background-color: #172554;
		height: 30px;

		border-radius: 0.5rem;
		overflow: hidden;
		isolation: isolate;
	}}

	#progress-bar {{
		width: 0;
		height: 100%;
		background-color: #1d4ed8;
		transition: width 1s ease-in-out;
	}}

	#progress-label-container {{
		position: absolute;
		top: 0;
		left: 0;

		width: 100%;
		height: 100%;

		display: flex;
		justify-content: center;
		align-items: center;

		gap: 0.5rem;
	}}
</style>

<img id="bouncing_image" src="{bouncing_img_url}" />
<div id="progress-container">
    <div id="progress-bar"> </div>

    <div id="progress-label-container">
        <svg id="animate-spin" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24" fill="none" stroke="currentColor" stroke-width="2" stroke-linecap="round" stroke-linejoin="round" class="lucide lucide-loader-2"><path d="M21 12a9 9 0 1 1-6.219-8.56"/></svg>
        <span id="progress-label"> 0% <span>
    </div>
</div>

<script>
    function updateProgress(progress) {{
        let bar = document.getElementById("progress-bar");
        let label = document.getElementById("progress-label");

        bar.style.width = progress + '%';
        label.innerText = progress + '%';
    }}
</script>

<audio id="elevator_music" src="{audio_file}" controls autoplay loop></audio>
"""
html_end = """
<script>
document.getElementById('elevator_music').pause();
document.getElementById("bouncing_image").remove();
document.getElementById("progress-bar").remove();
document.getElementById("progress-label-container").remove()
document.getElementById("progress-container").remove()
</script>
"""
html_snd = f"""
<audio id="elevator_music" src="https://henk.tech/colabkobold/silence.m4a" autoplay loop style="display:none">
</audio>
"""
# title and empty subtitle
header_widget = HTML(value="""
<div id='header-container'>
	<h2> Stable Diffusion Setup </h2>
	<span> ㅤ </span>
</div>
""")

# Define a specific layout for the dropdown
layout = widgets.Layout(width='auto')
model_menu_layout = widgets.Layout(width='600px')

# Create a description widget
description_widget = HTML(value="<span id='select-label' > <b>Choose SD Model:</b> </span>")
model_dropdown = widgets.Dropdown(options=mapped_model_list,layout=model_menu_layout,)
# Combine description and dropdown into a horizontal box
combined_widget = widgets.VBox([header_widget, widgets.HBox([description_widget, model_dropdown])])
# Create checkboxes for different options
Controlnet_checkbox = widgets.ToggleButton(value=True, description="Download and installs Controlnet extension", layout=layout)
Lora_pack_checkbox = widgets.ToggleButton(value=True, description="Download a set of Lora and LyCORIS models (increases setup time)", layout=layout)
Ram_optimization_checkbox = widgets.ToggleButton(value=True, description="Optimize RAM (increases generation time by a few seconds)", layout=layout)
Autostart_checkbox = widgets.ToggleButton(value=True, description="Automatically start SD without the need to start it with a separate cell", layout=layout)

toggle_buttons_grid = VBox([
    HBox([Controlnet_checkbox, Lora_pack_checkbox]),
    HBox([Ram_optimization_checkbox, Autostart_checkbox])
])

# Create finish button
continue_button = widgets.Button(description="Finish SD setup")

# Function to handle button click
def on_button_click(b):
    global exit_setup
    global Model
    global selected_link
    global Controlnet
    global Lora_pack
    global Ram_optimization
    global Autostart

    # Access the selected values
    selected_link = model_dropdown.value
    Controlnet = Controlnet_checkbox.value
    Lora_pack = Lora_pack_checkbox.value
    Ram_optimization = Ram_optimization_checkbox.value
    Autostart = Autostart_checkbox.value

    exit_setup = True

# Bind the function to the button
continue_button.on_click(on_button_click)

# Display the widgets

display(custom_css)
display(combined_widget)
display(toggle_buttons_grid)
display(continue_button)

# Wait loop with ui_events
with ui_events() as poll:
    while not exit_setup:
        poll(10)  # poll queued UI events including button
        time.sleep(0.1)  # Sleep to reduce CPU usage


combined_widget.close()
Controlnet_checkbox.close()
Lora_pack_checkbox.close()
Ram_optimization_checkbox.close()
Autostart_checkbox.close()
continue_button.close()
display(HTML(Html_start))

os.chdir('/content')

def update_progress(progress):
    display(Javascript('updateProgress({})'.format(progress)))

match os.path.exists("/content/stable/models/Stable-diffusion"):
    case False:

        os.chdir('/content')
        commands = [
        "sudo apt-get install libcairo2-dev pkg-config python3-dev",
        "git clone https://github.com/SELEKCJONER/stable.git",
        "git clone https://github.com/SELEKCJONER/SDLyCO.git /content/stable/extensions/LyCORIS",
        "git clone https://github.com/doctord98/imgbrower.git /content/stable/extensions/imgbrowser",
        "git clone https://github.com/SELEKCJONER/CH.git /content/stable/extensions/civitai-helper",
        "git clone https://github.com/doctord98/openpose-editor.git /content/stable/extensions/openpose-editor",
        "git clone https://github.com/doctord98/tags.git /content/stable/extensions/tags"
    ]

        # Execute commands and hide their output
        for command in commands:
            subprocess.call(command, shell=True, stdout=subprocess.DEVNULL,stderr=subprocess.DEVNULL)

    case _:
        pass

update_progress(30)
match Ram_optimization:
  case True:
    subprocess.call(["aria2c", "-x 10", "-s 10", "-j 10", "-c", "-o libtcmalloc_minimal.so.4", "--file-allocation=none", "https://huggingface.co/SELEKCJONER/sdfiles/resolve/main/libtcmalloc_minimal.so.4"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    subprocess.call(["env", "LD_PRELOAD=/content/libtcmalloc_minimal.so.4"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
  case _:
       pass
try:
    os.chdir('/content/stable/models/Stable-diffusion/')
    index = model_list[1].index(selected_link)
    model = model_list[0][index]
    # Download model file
    file_name = model + ".safetensors"
    subprocess.call(["aria2c", "-x 10", "-s 10", "-j 10", "-c", f"-o {file_name}", "--file-allocation=none", selected_link], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    # Download VAE
    vae_file_name = model + ".vae.safetensors"
    subprocess.call(["aria2c", "-x 10", "-s 10", "-j 10", "-c", f"-o {vae_file_name}", "--file-allocation=none", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

except ValueError:
    print(f"Unknown model: {model}")

update_progress(50)
match Controlnet:
    case True:
        match os.path.exists("/content/stable/extensions/contra"):
          case False:
            subprocess.call(["git", "clone", "https://github.com/doctord98618/contra.git", "/content/stable/extensions/contra"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
            os.chdir("/content/stable/extensions/contra/models/")
            subprocess.call(["aria2c", "-x 10", "-s 10", "-j 10", "-c", "-o control_v11p_sd15_canny.pth", "--file-allocation=none", "https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny.pth"])
            subprocess.call(["aria2c", "-x 10", "-s 10", "-j 10", "-c", "-o control_v11f1p_sd15_depth.pth", "--file-allocation=none", "https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11f1p_sd15_depth.pth"])
            subprocess.call(["aria2c", "-x 10", "-s 10", "-j 10", "-c", "-o control_v11p_sd15_openpose.pth", "--file-allocation=none", "https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose.pth"])
          case _:
              pass
    case _:
        pass
match Lora_pack:
  case True:
      match os.path.exists("/content/stable/models/LyCORIS"):
        case False:
          subprocess.call(["mkdir", "/content/stable/models/LyCORIS"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
          os.chdir("/content/stable/models/LyCORIS")
          subprocess.call(["aria2c", "-x 10", "-s 10", "-j 10", "-c", "-o Lora.zip", "--file-allocation=none", "https://huggingface.co/SELEKCJONER/sdfiles/resolve/main/Lora.zip"])
          subprocess.call(["unzip", "/content/stable/models/LyCORIS/Lora.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
          subprocess.call(["rm", "/content/stable/models/LyCORIS/Lora.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
          subprocess.call(["mkdir", "/content/stable/models/ESRGAN"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
          os.chdir("/content/stable/models/ESRGAN")
          subprocess.call(["aria2c", "-x 10", "-s 10", "-j 10", "-c", "-o ESRGAN.zip", "--file-allocation=none", "https://huggingface.co/nolanaatama/colab/resolve/main/upscalers.zip"])
          subprocess.call(["unzip", "/content/stable/models/ESRGAN/ESRGAN.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
          subprocess.call(["rm", "ESRGAN.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
          subprocess.call(["aria2c", "-x 10", "-s 10", "-j 10", "-c", "-o 4x_ArtStation1337_v2.pth", "--file-allocation=none", "https://huggingface.co/Duskfallcrew/my_merged_models/resolve/main/Upscaler_Backup/4x_ArtStation1337_v2.pth"])
          os.chdir("/content/stable")
          update_progress(70)
        case _:
             update_progress(70)
             pass
  case _:
      update_progress(70)
      pass

match Nuri_extensions:
    case True:
      os.chdir("/content/stable/")
      subprocess.call(["aria2c", "-x 10", "-s 10", "-j 10", "-c", "-o embeddings.zip", "--file-allocation=none", "https://huggingface.co/nolanaatama/colab/resolve/main/embeddings.zip"])
      update_progress(70)
      subprocess.call(["unzip", "/content/stable/embeddings.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      os.chdir("/content/stable/extensions/")
      subprocess.call(["aria2c", "-x 10", "-s 10", "-j 10", "-c", "-o ext.zip", "--file-allocation=none", "https://huggingface.co/SELEKCJONER/sdfiles/resolve/main/ext1.zip"])
      subprocess.call(["aria2c", "-x 10", "-s 10", "-j 10", "-c", "-o aspectratiohelper.zip", "--file-allocation=none", "https://huggingface.co/NuriDerBurrito/Burritoext/resolve/main/aspectratiohelper.zip"])
      os.chdir("/content/stable/extensions")
      subprocess.call(["unzip", "/content/stable/extensions/ext.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["unzip", "/content/stable/extensions/aspectratiohelper.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      os.chdir("/content/stable")
      update_progress(80)
    case _:
        update_progress(80)
        pass
match Nuri_embeddings:
  case True:
    os.chdir('/content/stable/embeddings')
    subprocess.call(["aria2c", "-x 10", "-s 10", "-j 10", "-c", "-o style-swirlmagic.pt", "--file-allocation=none", "https://civitai.com/api/download/models/30926"])
    subprocess.call(["aria2c", "-x 10", "-s 10", "-j 10", "-c", "-o Mangastyle.pt", "--file-allocation=none", "https://civitai.com/api/download/models/84156"])
    subprocess.call(["aria2c", "-x 10", "-s 10", "-j 10", "-c", "-o Fixhand.pt", "--file-allocation=none", "https://civitai.com/api/download/models/111363"])
    subprocess.call(["aria2c", "-x 10", "-s 10", "-j 10", "-c", "-o PunchIt_NegV1.pt", "--file-allocation=none", "https://civitai.com/api/download/models/111411"])
    update_progress(90)
  case _:
      update_progress(100)
      pass
os.chdir('/content/stable')

display(HTML(html_end))
display(HTML(html_snd))
match Autostart:
    case True:
        try:
            display(running_css)
            while True:
                # !COMMANDLINE_ARGS="--share --allow-code --no-hashing --xformers --no-half-vae --disable-safe-unpickle --enable-insecure-extension-access" REQS_FILE="requirements.txt" python launch.py
        except KeyboardInterrupt:
            try:
                while True:
                    # !COMMANDLINE_ARGS="--share --allow-code --no-hashing --xformers --no-half-vae --disable-safe-unpickle --enable-insecure-extension-access" REQS_FILE="requirements.txt" python launch.py
            except KeyboardInterrupt:
                pass
    case _:
        update_progress(100)
        pass

display(HTML(html_end))
display(HTML(html_snd))

print('done, you can download more models or launch below')

# %%
#@title Run this to restart SD or start it if you deselected autostart { display-mode: "form" }
from IPython.display import display, HTML
custom_css = HTML("""
<style>
    /*cell output these values are used instead of default shit from above*/
    html[theme=dark] {
        background: url(https://ik.imagekit.io/gmethsnvl/99049667_p0_Mt0h-4UhU.png) !important;
        background-size: cover !important;
        background-position: center !important;
        background-repeat: no-repeat !important;

		display: flex !important;
		justify-content: center !important;
		align-items: center !important;

        --colab-primary-surface-color: transparent !important; /* Darker output cell bg */
        --colab-secondary-surface-color: #5e0000 !important; /* Darker output cell dropdown and continue button */
        --jp-ui-font-color1: #a0a0a0 !important; /* Darker every button font color */
        --jp-widgets-color: #a0a0a0 !important; /* Darker non-button text color */
        --jp-ui-font-color1: white !important;
        --jp-layout-color2: #1d5e00 !important;

        --jp-widgets-input-background-color: var(--jp-layout-color1) !important;
        --jp-widgets-label-color: var(--jp-widgets-color) !important;
        --jp-widgets-readout-color: var(--jp-widgets-color) !important;
        --jp-widgets-font-size: var(--jp-ui-font-size1) !important;
        --jp-widgets-margin: 2px !important;
        --jp-widgets-inline-height: max-content !important;
        --jp-widgets-inline-width: 300px !important;
        --jp-widgets-inline-width-short: calc(var(--jp-widgets-inline-width) / 2 - var(--jp-widgets-margin)) !important;
        --jp-widgets-inline-width-tiny: calc(var(--jp-widgets-inline-width-short) / 2 - var(--jp-widgets-margin)) !important;
        --jp-widgets-inline-margin: 4px !important;
        --jp-widgets-inline-label-width: 80px !important;
        --jp-widgets-border-width: var(--jp-border-width) !important;
        --jp-widgets-vertical-height: 200px !important;
        --jp-widgets-horizontal-tab-height: 24px !important;
        --jp-widgets-horizontal-tab-width: 144px !important;
        --jp-widgets-horizontal-tab-top-border: 2px !important;
        --jp-widgets-progress-thickness: 20px !important;
        --jp-widgets-container-padding: 15px !important;
        --jp-widgets-input-padding: 4px !important;
        --jp-widgets-radio-item-height-adjustment: 8px !important;
        --jp-widgets-radio-item-height: calc(var(--jp-widgets-inline-height) - var(--jp-widgets-radio-item-height-adjustment)) !important;
        --jp-widgets-slider-track-thickness: 4px !important;
        --jp-widgets-slider-border-width: var(--jp-widgets-border-width) !important;
        --jp-widgets-slider-handle-size: 16px !important;
        --jp-widgets-slider-handle-border-color: var(--jp-border-color1) !important;
        --jp-widgets-slider-handle-background-color: var(--jp-layout-color1) !important;
        --jp-widgets-slider-active-handle-color: var(--jp-brand-color1) !important;
        --jp-widgets-menu-item-height: 24px !important;
        --jp-widgets-input-color: var(--jp-ui-font-color1) !important;
        --jp-widgets-input-border-color: var(--jp-border-color1) !important;
        --jp-widgets-input-focus-border-color: var(--jp-brand-color2) !important;
        --jp-widgets-input-border-width: var(--jp-widgets-border-width) !important;
        --jp-widgets-disabled-opacity: 0.6 !important;
        --md-shadow-key-umbra-opacity: 0.2 !important;
        --md-shadow-key-penumbra-opacity: 0.14 !important;
        --md-shadow-ambient-shadow-opacity: 0.12 !important;
    }


    button {
        border: 1px solid #d4d4d4;
        border-radius: .5rem;

		color: #ab4390;
		padding: .5rem 1rem !important;
    }

    .widget-toggle-button {
        background-color: #dc262699;
        transition: background .25s linear;
    }

    .widget-toggle-button .widget-label {
        text-align: left;
        width: 100%;
    }

    .widget-toggle-button.jupyter-button:active,
    .jupyter-button.mod-active {
        background-color: #16a34a99 !important;

    }

    .widget-html > .widget-html-content,
    .widget-htmlmath > .widget-html-content {
        /* backdrop-filter: blur(10px) !important; */
        color: var(--jp-ui-font-color1);
    }

    @keyframes selectGradient {
        0% {
            background: #ab438f99;
        }
        25% {
            background: #d35a7499;
        }
        50% {
            background: #af4b6999;
        }
        75% {
            background: #d35a7499;
        }
        100% {
            background: #ab438f99;
        }
    }

    @keyframes optionGradient {
        0% {
            background: #ab438f;
        }
        25% {
            background: #d35a74;
        }
        50% {
            background: #af4b69;
        }
        75% {
            background: #d35a74;
        }
        100% {
            background: #ab438f;
        }
    }

	@keyframes glow {
		0%,
		100% {
			box-shadow: 0 0 3px #ab438f, 0 0 5px #ab438f, 0 0 8px #ab438f, 0 0 10px #ab438f;
		}
		25%, 75% {
			box-shadow: 0 0 6px #d35a74BF, 0 0 5px #d35a74BF, 0 0 8px #d35a74BF, 0 0 10px #d35a74BF;
		}
		50% {
			box-shadow: 0 0 10px #ab438f80, 0 0 20px #ab438f80, 0 0 30px #ab438f80, 0 0 40px #ab438f80;
		}
	}

	#header-container {
		margin: 0;
		padding: 0.5rem 1rem 1rem 1rem;
		text-align: center;
		display: flex;
		flex-direction: column;
		gap: 0.25rem;
	}

	#header-container h2 {
		margin: 0;
		padding: 0;
		font-size: xx-large;
	}

	#header-container span {
		font-size: small;
		color: gray;
	}

	#select-label {
		height: 100%;
		color: #af4b69;

		display: flex;
		justify-content: center;
		align-items: center;
	}

	.widget-dropdown:has(select) {
		height: max-content;
		display: flex;

		gap: 0.5rem;
		justify-content: center;
		align-items: center;
	}

    .widget-dropdown > select {
        background: #ab438f99;
        backdrop-filter: blur(4px) saturate(1.5);

        animation: selectGradient 3s linear infinite;
        height: max-content !important;

        padding: 0.5rem 1rem;

        border: 1px solid white;
        border-radius: 0.5rem;
    }

	/* For dropdown menu rollout formatting */
    option {
        background: #ab438f;
        animation: optionGradient 3s linear infinite;
        border-radius: 0.5rem;
    }

	#output-area {
		min-height: 600px;
		display: flex !important;
        flex-direction: column;

		justify-content: center;
		align-items: center;
        gap: 0.5rem;
	}

	#output-body {
		height: max-content;

		display: flex !important;
        flex-direction: column;

		justify-content: center;
		align-items: center;
        gap: 0.5rem;

		padding: 1rem !important;
		background: #241431b3;
		backdrop-filter: blur(12px) saturate(1.5);;

		border: 4px solid rgb(171 67 144);
		border-radius: 0.5rem;

		animation: glow 2s ease-in-out infinite;
	}

	/* Error output */
	div.error.output-id-5.output-error {
		padding: 0.5rem 1rem;
	}

	div.error.output-id-5.output-error::before {
		content: "Error";

		display: block;
		text-align: center;

		color: #e2717e;
		font-size: x-large;
		font-weight: 700;
	}
</style>
""")
running_css = HTML("""
	<style>
div.stream, div.execute_result, div.output_text, div.output_text pre {
    display: inline;
    white-space: pre-line;
    overflow: hidden;
    text-overflow: ellipsis;
    transform: scale(0.9);
    overflow-y: auto;

}
	#output-body {
		max-width: 600px !important;
    max-height: 500px;
    gap: unset !important;
	}
div.stream::-webkit-scrollbar {
    display: none;
}

   </style>
   <script>
document.addEventListener("DOMContentLoaded", function() {
  const scrollingElement = document.querySelector("div.output_text pre");

  if (scrollingElement) {
    const config = { childList: true };

    const callback = function (mutationsList, observer) {
      for (let mutation of mutationsList) {
        if (mutation.type === "childList") {
          scrollingElement.scrollTop = scrollingElement.scrollHeight;
        }
      }
    };

    const observer = new MutationObserver(callback);
    observer.observe(scrollingElement, config);
  } else {
    console.error("Element not found!");
  }
});


  </script>
""")
display(custom_css)
display(running_css)
# %cd /content/stable

try:
    while True:
        # !COMMANDLINE_ARGS="--share --allow-code --no-hashing --xformers --no-half-vae --disable-safe-unpickle --enable-insecure-extension-access" REQS_FILE="requirements.txt" python launch.py
except KeyboardInterrupt:
    try:
        while True:
            # !COMMANDLINE_ARGS="--share --allow-code --no-hashing --xformers --no-half-vae --disable-safe-unpickle --enable-insecure-extension-access" REQS_FILE="requirements.txt" python launch.py
    except KeyboardInterrupt:
        pass

# %%
#@title Use  this to save or load SD to/from gdrive{ display-mode: "form" }
from google.colab import drive
import os
Mode = "Save" #@param ["Save","Load"]
path_exists = os.path.exists('/content/drive/')
match path_exists:
    case False:
        drive.mount('/content/drive')
    case _:
      pass

match Mode:
  case "Save":
    # !cp -r /content/stable/ /content/drive/MyDrive/
  case "Load":
    # !cp -r /content/drive/MyDrive/stable /content/stable/
  case _:
    pass

# %% [markdown]
# # <center><font color="94cfff">Dev Zone</font>
# <center>Nothing interesting here

# %%
#@title Dev zone - loading effects { display-mode: "form" }
import random
from IPython.display import display, HTML
from IPython.display import Javascript
import time

felix = "https://files.catbox.moe/ah0ool.webp"
emilia = "https://files.catbox.moe/a3pzd6.webp"
rem = "https://files.catbox.moe/iok7nh.webp"
ram = "https://files.catbox.moe/052ul1.webp"

bouncing_img_url_list = [felix,emilia,rem,ram]
bouncing_img_url = random.choices(bouncing_img_url_list, weights=[1,1,1,1])[0]
audio_file = "https://files.catbox.moe/5pz0yq.mp3"


Html_start = f"""
<style>
@keyframes bounce {{
    0% {{   margin-left: 0%;    }}
    50% {{  margin-left: 70%;   }}
    100% {{ margin-left: 0%;    }}
}}

@keyframes spin {{
    from {{
        transform: rotate(0deg);
    }}
    to {{
        transform: rotate(360deg);
    }}
}}

#animate-spin {{
    animation: spin 1s linear infinite;

    width: 16px;
    height: 16px;
}}

#bouncing_image {{
    position: relative;
    width: 400px;
    animation: bounce 13s linear infinite;

    border-radius: 0.5rem;
}}

#elevator_music {{
    display: none;
}}

#progress-container {{
    position: relative;

    width: 99%;
    background-color: #172554;
    height: 30px;

    border-radius: 0.5rem;
    overflow: hidden;
    isolation: isolate;
}}

#progress-bar {{
    width: 0;
    height: 100%;
    background-color: #1d4ed8;
    transition: width 1s ease-in-out;
}}

#progress-label-container {{
    position: absolute;
    top: 0;
    left: 0;

    width: 100%;
    height: 100%;

    display: flex;
    justify-content: center;
    align-items: center;

    gap: 0.5rem;
}}
</style>

<img id="bouncing_image" src="{bouncing_img_url}" />
<div id="progress-container">
    <div id="progress-bar"> </div>

    <div id="progress-label-container">
        <svg id="animate-spin" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24" fill="none" stroke="currentColor" stroke-width="2" stroke-linecap="round" stroke-linejoin="round" class="lucide lucide-loader-2"><path d="M21 12a9 9 0 1 1-6.219-8.56"/></svg>

        <span id="progress-label"> 0% <span>
    </div>
</div>

<script>
    function updateProgress(progress) {{
        let bar = document.getElementById("progress-bar");
        let label = document.getElementById("progress-label");

        bar.style.width = progress + '%';
        label.innerText = progress + '%';
    }}
</script>

<audio id="elevator_music" src="{audio_file}" controls autoplay loop>
</audio>
"""

display(HTML(Html_start))
time.sleep(3)

def update_progress(progress):
    display(Javascript('updateProgress({})'.format(progress)))

# Example usage
update_progress(30)
time.sleep(6)
update_progress(60)
time.sleep(6)
update_progress(100)
time.sleep(6)
html_end="""
<script>
    document.getElementById("progress-container").remove();
</script>
"""
#display(HTML(html_end))

# %%
# @title Dev zone - try custom theme high cpu usage
import subprocess
import os
os.chdir("/content/stable/extensions")
subprocess.call(["curl", "-Lo", "/content/stable/extensions/newui.zip", "https://huggingface.co/CasanovaSan/SDFILES/resolve/main/new_theme-2.8.6.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
subprocess.call(["unzip", "/content/stable/extensions/newui.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

# %%
#@title Dev - zone new ui tests { display-mode: "form" }

#@markdown <font color="#94cfff"> Just run this cell to open setup inerface
import random
import os
from IPython.display import display, HTML
from IPython.display import Javascript
import subprocess
subprocess.call(["pip", "install","jupyter_ui_poll"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
from jupyter_ui_poll import ui_events
import ipywidgets as widgets
from IPython.display import display
import time
from ipywidgets import HTML, VBox, HBox
from IPython.display import clear_output

exit_setup = False

# Define the models list
model_list = ["Pixai real v3 (realistic)", "Magicmix v5 (realistic)", "Chilloutmix v2 (realistic)", "Dreamshaper (semi realistic)", "Lyriel (semi realistic)", "Fentexi (2.5D)", "Yabalmix (2.5D)", "Rev animated (2.5D)", "Kyumix v1 (anime)", "Replicant v3 (anime)", "Moyu (anime)", "Counterfeit v3 (anime)", "Ruvimix v2 (anime)", "Meinamix v10 (anime)", "Camilia mix (anime)", "Yabalmix v3 (anime)", "Manmaru mix (cartoon)", "Meinahentai v3 (anime)", "Meinapastal v5 (anime)", "anylora (anime)","Model-EX", "JASMix 3.0 [Just Another Stylized Model]", "MiracleMix", "disneypixar", "disneypixar_Type A", "disneypixar_type B", "IdentityCrisis", "VinteProtogenMix", "Perfect World", "Remedy", "CompassionMix", "BokoMix", "DonutHoleMix", "Project KR4X - 2.5D / AaYMix", "Pastel-Mix [Stylized Anime Model]", "MeinaMix", "Anything V5", "AbyssOrangeMix3", "DarkRevPikas", "OS-Ambrosia", "Epic Mix - V3", "MechaMix", "Ageless", "Mymix", "TMND-Mix", "dosmix", "abstract anim spritesheets", "Corneros 7th Heaven Mix", "Identity Disorder", "Epic Mix", "MIXPROV4", "Nyan mix", "viewer-mix_v1.7", "MoonTea", "ToonYou", "CoffeeMix","Sardonyx Redux", "SCH Excelsior","Ametrine REDUX", "Dark Sushi Mix", "Galena Redux", "Hassaku Hentai", "SakushiMix Hentai","RealCartoon3D","exquisiteDetails_v10","4cheemsblend_v10","Break domain anime","Yabalmix v5", "Sleeplessmix v1", "DarkrevPikas v3", "ModelEX v2.5", "AbyssOrange2xAnyv4", "end_v10", "envyoverdrivexl_v10DS", "nixesmix_v10", "toonyouJP_alpha1", "blazingDrive_v03", "camelliamix_v3", "darkSushiMixMix_colorful", "darkSushi25D25D_v30", "darkSushiMixMix_darkerPruned", "duchaitenThiccboi_v10", "kizukiAnimeHentai_animeHentaiV3", "nabimix_v2", "orangeGalenyxMerge_v11", "renaigadeFantasy_v10", "ultraInfinityAnime_v2Yamime", "yogirimix_v10","maturemalemix","Lawlas's Yiffymix 2.0 (furry model)","YiffyMix 3.2 (furry model)","Coconut furry mix (furry model)"]

# Define a specific layout for the dropdown
layout = widgets.Layout(width='auto')
model_menu_layout = widgets.Layout(width='600px')

# Create a header widget <span> is a label bellow title
header_widget = HTML(value="""
<div id='header-container'>
	<h2> Stable Diffusion Setup </h2>
	<span> ㅤ </span>
</div>
""")

# Create a description widget
description_widget = HTML(value="<span id='select-label' > <b>Choose SD Model:</b> </span>")

# Create a dropdown for model selection using the above layout
model_dropdown = widgets.Dropdown(
    options=model_list,
    layout=model_menu_layout,
)

# Combine description and dropdown into a horizontal box
combined_widget = widgets.VBox([header_widget, widgets.HBox([description_widget, model_dropdown])])

# Create checkboxes for different options
Controlnet_checkbox = widgets.ToggleButton(value=True, description="Download and installs Controlnet extension", layout=layout)
Lora_pack_checkbox = widgets.ToggleButton(value=True, description="Download a set of Lora and LyCORIS models (increases setup time)", layout=layout)
Ram_optimization_checkbox = widgets.ToggleButton(value=True, description="Optimize RAM (increases generation time by a few seconds)", layout=layout)
Autostart_checkbox = widgets.ToggleButton(value=True, description="Automatically start SD without the need to start it with a separate cell", layout=layout)

# Define custom CSS for toggle button states
custom_css = HTML("""
<style>
    /*cell output these values are used instead of default shit from above*/
    html[theme=dark] {
        background: url(https://ik.imagekit.io/gmethsnvl/99049667_p0_Mt0h-4UhU.png) !important;
        background-size: cover !important;
        background-position: center !important;
        background-repeat: no-repeat !important;

		display: flex !important;
		justify-content: center !important;
		align-items: center !important;

        --colab-primary-surface-color: transparent !important; /* Darker output cell bg */
        --colab-secondary-surface-color: #5e0000 !important; /* Darker output cell dropdown and continue button */
        --jp-ui-font-color1: #a0a0a0 !important; /* Darker every button font color */
        --jp-widgets-color: #a0a0a0 !important; /* Darker non-button text color */
        --jp-ui-font-color1: white !important;
        --jp-layout-color2: #1d5e00 !important;

        --jp-widgets-input-background-color: var(--jp-layout-color1) !important;
        --jp-widgets-label-color: var(--jp-widgets-color) !important;
        --jp-widgets-readout-color: var(--jp-widgets-color) !important;
        --jp-widgets-font-size: var(--jp-ui-font-size1) !important;
        --jp-widgets-margin: 2px !important;
        --jp-widgets-inline-height: max-content !important;
        --jp-widgets-inline-width: 300px !important;
        --jp-widgets-inline-width-short: calc(var(--jp-widgets-inline-width) / 2 - var(--jp-widgets-margin)) !important;
        --jp-widgets-inline-width-tiny: calc(var(--jp-widgets-inline-width-short) / 2 - var(--jp-widgets-margin)) !important;
        --jp-widgets-inline-margin: 4px !important;
        --jp-widgets-inline-label-width: 80px !important;
        --jp-widgets-border-width: var(--jp-border-width) !important;
        --jp-widgets-vertical-height: 200px !important;
        --jp-widgets-horizontal-tab-height: 24px !important;
        --jp-widgets-horizontal-tab-width: 144px !important;
        --jp-widgets-horizontal-tab-top-border: 2px !important;
        --jp-widgets-progress-thickness: 20px !important;
        --jp-widgets-container-padding: 15px !important;
        --jp-widgets-input-padding: 4px !important;
        --jp-widgets-radio-item-height-adjustment: 8px !important;
        --jp-widgets-radio-item-height: calc(var(--jp-widgets-inline-height) - var(--jp-widgets-radio-item-height-adjustment)) !important;
        --jp-widgets-slider-track-thickness: 4px !important;
        --jp-widgets-slider-border-width: var(--jp-widgets-border-width) !important;
        --jp-widgets-slider-handle-size: 16px !important;
        --jp-widgets-slider-handle-border-color: var(--jp-border-color1) !important;
        --jp-widgets-slider-handle-background-color: var(--jp-layout-color1) !important;
        --jp-widgets-slider-active-handle-color: var(--jp-brand-color1) !important;
        --jp-widgets-menu-item-height: 24px !important;
        --jp-widgets-input-color: var(--jp-ui-font-color1) !important;
        --jp-widgets-input-border-color: var(--jp-border-color1) !important;
        --jp-widgets-input-focus-border-color: var(--jp-brand-color2) !important;
        --jp-widgets-input-border-width: var(--jp-widgets-border-width) !important;
        --jp-widgets-disabled-opacity: 0.6 !important;
        --md-shadow-key-umbra-opacity: 0.2 !important;
        --md-shadow-key-penumbra-opacity: 0.14 !important;
        --md-shadow-ambient-shadow-opacity: 0.12 !important;
    }


    button {
        border: 1px solid #d4d4d4;
        border-radius: .5rem;

		color: #ab4390;
		padding: .5rem 1rem !important;
    }

    .widget-toggle-button {
        background-color: #dc262699;
        transition: background .25s linear;
    }

    .widget-toggle-button .widget-label {
        text-align: left;
        width: 100%;
    }

    .widget-toggle-button.jupyter-button:active,
    .jupyter-button.mod-active {
        background-color: #16a34a99 !important;

    }

    .widget-html > .widget-html-content,
    .widget-htmlmath > .widget-html-content {
        /* backdrop-filter: blur(10px) !important; */
        color: var(--jp-ui-font-color1);
    }

    @keyframes selectGradient {
        0% {
            background: #ab438f99;
        }
        25% {
            background: #d35a7499;
        }
        50% {
            background: #af4b6999;
        }
        75% {
            background: #d35a7499;
        }
        100% {
            background: #ab438f99;
        }
    }

    @keyframes optionGradient {
        0% {
            background: #ab438f;
        }
        25% {
            background: #d35a74;
        }
        50% {
            background: #af4b69;
        }
        75% {
            background: #d35a74;
        }
        100% {
            background: #ab438f;
        }
    }

	@keyframes glow {
		0%,
		100% {
			box-shadow: 0 0 3px #ab438f, 0 0 5px #ab438f, 0 0 8px #ab438f, 0 0 10px #ab438f;
		}
		25%, 75% {
			box-shadow: 0 0 6px #d35a74BF, 0 0 5px #d35a74BF, 0 0 8px #d35a74BF, 0 0 10px #d35a74BF;
		}
		50% {
			box-shadow: 0 0 10px #ab438f80, 0 0 20px #ab438f80, 0 0 30px #ab438f80, 0 0 40px #ab438f80;
		}
	}

	#header-container {
		margin: 0;
		padding: 0.5rem 1rem 1rem 1rem;
		text-align: center;
		display: flex;
		flex-direction: column;
		gap: 0.25rem;
	}

	#header-container h2 {
		margin: 0;
		padding: 0;
		font-size: xx-large;
	}

	#header-container span {
		font-size: small;
		color: gray;
	}

	#select-label {
		height: 100%;
		color: #af4b69;

		display: flex;
		justify-content: center;
		align-items: center;
	}

	.widget-dropdown:has(select) {
		height: max-content;
		display: flex;

		gap: 0.5rem;
		justify-content: center;
		align-items: center;
	}

    .widget-dropdown > select {
        background: #ab438f99;
        backdrop-filter: blur(4px) saturate(1.5);

        animation: selectGradient 3s linear infinite;
        height: max-content !important;

        padding: 0.5rem 1rem;

        border: 1px solid white;
        border-radius: 0.5rem;
    }

	/* For dropdown menu rollout formatting */
    option {
        background: #ab438f;
        animation: optionGradient 3s linear infinite;
        border-radius: 0.5rem;
    }

	#output-area {
		min-height: 600px;
		display: flex !important;
        flex-direction: column;

		justify-content: center;
		align-items: center;
        gap: 0.5rem;
	}

	#output-body {
		height: max-content;

		display: flex !important;
        flex-direction: column;

		justify-content: center;
		align-items: center;
        gap: 0.5rem;

		padding: 1rem !important;
		background: #241431b3;
		backdrop-filter: blur(12px) saturate(1.5);;

		border: 4px solid rgb(171 67 144);
		border-radius: 0.5rem;

		animation: glow 2s ease-in-out infinite;
	}

	/* Error output */
	div.error.output-id-5.output-error {
		padding: 0.5rem 1rem;
	}

	div.error.output-id-5.output-error::before {
		content: "Error";

		display: block;
		text-align: center;

		color: #e2717e;
		font-size: x-large;
		font-weight: 700;
	}
</style>
""")

toggle_buttons_grid = VBox([
    HBox([Controlnet_checkbox, Lora_pack_checkbox]),
    HBox([Ram_optimization_checkbox, Autostart_checkbox])
])

# Nuri_embeddings and extensions are always set to True
Nuri_embeddings = True
Nuri_extensions = True

# Create a button to continue with code
continue_button = widgets.Button(description="Finish SD setup")

# Function to handle button click
def on_button_click(b):
    global exit_setup  			# Declare exit_setup as global
    global Model       			# Declare Model as global
    global Controlnet  			# Declare Controlnet as global
    global Lora_pack   			# Declare Lora_pack as global
    global Ram_optimization 	# Declare Ram_optimization as global
    global Autostart  			# Declare Autostart as global

    # Access the selected values
    Model = model_dropdown.value
    Controlnet = Controlnet_checkbox.value
    Lora_pack = Lora_pack_checkbox.value
    Ram_optimization = Ram_optimization_checkbox.value
    Autostart = Autostart_checkbox.value

    exit_setup = True

# Bind the function to the button
continue_button.on_click(on_button_click)

# Display the widgets

display(custom_css)
display(combined_widget)
display(toggle_buttons_grid)
display(continue_button)

# Wait loop with ui_events
with ui_events() as poll:
    while not exit_setup:
        poll(10)  # poll queued UI events including button
        time.sleep(0.1)  # Sleep to reduce CPU usage
clear_output()
felix = "https://files.catbox.moe/ah0ool.webp"
emilia = "https://files.catbox.moe/a3pzd6.webp"
rem = "https://files.catbox.moe/iok7nh.webp"
ram = "https://files.catbox.moe/052ul1.webp"

bouncing_img_url_list = [felix,emilia,rem,ram]
bouncing_img_url = random.choices(bouncing_img_url_list, weights=[1,1,1,1])[0]
audio_file = "https://files.catbox.moe/5pz0yq.mp3"


Html_start = f"""
<style>
	@keyframes bounce {{
		0% {{
        	margin-left: 0%;
        }}
		50% {{
			margin-left: 70%;
		}}
		100% {{
			margin-left: 0%;
		}}
	}}

	@keyframes spin {{
		from {{
			transform: rotate(0deg);
		}}
		to {{
			transform: rotate(360deg);
		}}
	}}

	#animate-spin {{
		animation: spin 1s linear infinite;

		width: 16px;
		height: 16px;
	}}

	#bouncing_image {{
		position: relative;
		width: 400px;
		animation: bounce 13s linear infinite;

		border-radius: 0.5rem;
	}}

	#elevator_music {{
		display: none;
	}}

	#progress-container {{
		position: relative;

		width: 99%;
		background-color: #172554;
		height: 30px;

		border-radius: 0.5rem;
		overflow: hidden;
		isolation: isolate;
	}}

	#progress-bar {{
		width: 0;
		height: 100%;
		background-color: #1d4ed8;
		transition: width 1s ease-in-out;
	}}

	#progress-label-container {{
		position: absolute;
		top: 0;
		left: 0;

		width: 100%;
		height: 100%;

		display: flex;
		justify-content: center;
		align-items: center;

		gap: 0.5rem;
	}}
</style>

<img id="bouncing_image" src="{bouncing_img_url}" />
<div id="progress-container">
    <div id="progress-bar"> </div>

    <div id="progress-label-container">
        <svg id="animate-spin" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24" fill="none" stroke="currentColor" stroke-width="2" stroke-linecap="round" stroke-linejoin="round" class="lucide lucide-loader-2"><path d="M21 12a9 9 0 1 1-6.219-8.56"/></svg>
        <span id="progress-label"> 0% <span>
    </div>
</div>

<script>
    function updateProgress(progress) {{
        let bar = document.getElementById("progress-bar");
        let label = document.getElementById("progress-label");

        bar.style.width = progress + '%';
        label.innerText = progress + '%';
    }}
</script>

<audio id="elevator_music" src="{audio_file}" controls autoplay loop></audio>
"""

display(HTML(Html_start))
def update_progress(progress):
    display(Javascript('updateProgress({})'.format(progress)))

# %%
import random
import os
import subprocess
from IPython.display import display, HTML
from IPython.display import Javascript
#@title Dev zone - old setup ui can be used as backup { display-mode: "form" }
Model = "Coconut furry mix (furry model)" #@param ["Pixai real v3 (realistic)", "Magicmix v5 (realistic)", "Chilloutmix v2 (realistic)", "Dreamshaper (semi realistic)", "Lyriel (semi realistic)", "Fentexi (2.5D)", "Yabalmix (2.5D)", "Rev animated (2.5D)", "Kyumix v1 (anime)", "Replicant v3 (anime)", "Moyu (anime)", "Counterfeit v3 (anime)", "Ruvimix v2 (anime)", "Meinamix v10 (anime)", "Camilia mix (anime)", "Yabalmix v3 (anime)", "Manmaru mix (cartoon)", "Meinahentai v3 (anime)", "Meinapastal v5 (anime)", "anylora (anime)","Model-EX", "JASMix 3.0 [Just Another Stylized Model]", "MiracleMix", "disneypixar", "disneypixar_Type A", "disneypixar_type B", "IdentityCrisis", "VinteProtogenMix", "Perfect World", "Remedy", "CompassionMix", "BokoMix", "DonutHoleMix", "Project KR4X - 2.5D / AaYMix", "Pastel-Mix [Stylized Anime Model]", "MeinaMix", "Anything V5", "AbyssOrangeMix3", "DarkRevPikas", "OS-Ambrosia", "Epic Mix - V3", "MechaMix", "Ageless", "Mymix", "TMND-Mix", "dosmix", "abstract anim spritesheets", "Corneros 7th Heaven Mix", "Identity Disorder", "Epic Mix", "MIXPROV4", "Nyan mix", "viewer-mix_v1.7", "MoonTea", "ToonYou", "CoffeeMix","Sardonyx Redux", "SCH Excelsior","Ametrine REDUX", "Dark Sushi Mix", "Galena Redux", "Hassaku Hentai", "SakushiMix Hentai","RealCartoon3D","exquisiteDetails_v10","4cheemsblend_v10","Break domain anime","Yabalmix v5", "Sleeplessmix v1", "DarkrevPikas v3", "ModelEX v2.5", "AbyssOrange2xAnyv4", "end_v10", "envyoverdrivexl_v10DS", "nixesmix_v10", "toonyouJP_alpha1", "blazingDrive_v03", "camelliamix_v3", "darkSushiMixMix_colorful", "darkSushi25D25D_v30", "darkSushiMixMix_darkerPruned", "duchaitenThiccboi_v10", "kizukiAnimeHentai_animeHentaiV3", "nabimix_v2", "orangeGalenyxMerge_v11", "renaigadeFantasy_v10", "ultraInfinityAnime_v2Yamime", "yogirimix_v10","Lawlas's Yiffymix 2.0 (furry model)","YiffyMix 3.2 (furry model)","Coconut furry mix (furry model)"]
Controlnet = True #@param {type:"boolean"}
Lora_pack = True #@param {type:"boolean"}
Ram_optimization = True #@param {type:"boolean"}
Nuri_embeddings = True #param {type:"boolean"}
Nuri_extensions = True #param {type:"boolean"}
#Custom_css = True #@param {type:"boolean"}
##@markdown > <font color="#94cfff"> *Experimental modded css may cause errors*
Autostart = True #@param {type:"boolean"}
#@markdown  <font color="#94cfff"> *Note* To stop code press run cell button a bunch of times and click on restart enviroment when asked also ram optimization may increase gen times
os.chdir('/content')
path = "/content/stable/models/Stable-diffusion"

bounce_duration = "13s"
bouncing_img_url_list = ["https://files.catbox.moe/8rt7v5.png","https://files.catbox.moe/e5q23x.png","https://files.catbox.moe/tzi975.png","https://files.catbox.moe/fl3va8.png"]
bouncing_img_url = random.choices(bouncing_img_url_list, weights=[1,1,1,1])[0]
audio_file = "https://files.catbox.moe/5pz0yq.mp3"


html_start = f"""
<style>
@keyframes bounce {{
  0% {{margin-left: 0%;}}
  50% {{margin-left: 70%;}}
  100% {{margin-left: 0%;}}
}}

#bouncing_image {{
  position: relative;
  width: 400px;
  animation: bounce {bounce_duration} linear infinite;
}}

#elevator_music {{
  display: none;
}}
#progress-container {{
    width: 99%;
    background-color: #383838;
    position: relative;
    height: 30px;
}}
#progress-bar {{
    width: 0;
    height: 100%;
    background-color: #0070f3;
    transition: width 2s;
}}
#progress-label {{
    position: absolute;
    top: -20px;
    left: 50%;
    transform: translateX(-50%);
}}
</style>

<img id="bouncing_image" src="{bouncing_img_url}" />
<div id="progress-container">
    <div id="progress-bar"></div>
<script>
function updateProgress(progress) {{
    var bar = document.getElementById("progress-bar");
    var label = document.getElementById("progress-label");
    bar.style.width = progress + '%';
}}
</script>
<audio id="elevator_music" src="{audio_file}" controls autoplay loop>
</audio>
"""
display(HTML(html_start))
def update_progress(progress):
    display(Javascript('updateProgress({})'.format(progress)))

match os.path.exists(path):
    case False:
#        print('please wait 😊')

        os.chdir('/content')

        # List of commands to execute
        commands = [
        "sudo apt-get install libcairo2-dev pkg-config python3-dev",
        "git clone https://github.com/SELEKCJONER/stable.git",
        "git clone https://github.com/SELEKCJONER/a1111-sd-webui-lycoris.git /content/stable/extensions/LyCORIS",
        "git clone https://github.com/doctord98/imgbrower.git /content/stable/extensions/imgbrowser",
        "git clone https://github.com/goldmojo/Stable-Diffusion-Webui-Civitai-Helper.git /content/stable/extensions/civitai-helper",
        "git clone https://github.com/doctord98/openpose-editor.git /content/stable/extensions/openpose-editor",
        "git clone https://github.com/doctord98/tags.git /content/stable/extensions/tags"
    ]

        # Execute commands and hide their output
        for command in commands:
            subprocess.call(command, shell=True, stdout=subprocess.DEVNULL,stderr=subprocess.DEVNULL)

    case _:
        pass

#print('downloading model')
update_progress(10)
match Ram_optimization:
  case True:
    subprocess.call(["curl", "-Lo", "libtcmalloc_minimal.so.4", "https://huggingface.co/SELEKCJONER/sdfiles/resolve/main/libtcmalloc_minimal.so.4"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
    subprocess.call(["env", "LD_PRELOAD=/content/libtcmalloc_minimal.so.4"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
  case _:
       pass

match Model:

  case "Pixai real v3 (realistic)":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/pixaireal.safetensors","https://huggingface.co/WolfAether21/chilled_re-generic_v3/resolve/main/chilledReGenericV3_v10.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/pixaireal.vae.safetensors","https://huggingface.co/doctord98/stable/resolve/main/vae.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Film grain v2 (realistic)":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/filmgrain.safetensors","https://huggingface.co/doctord98/stable/resolve/main/filmgrainv2.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Magicmix v5 (realistic)":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/magicreal.safetensors","https://huggingface.co/sinkinai/majicMIX-realistic-v5/resolve/main/majicmixRealistic_v5.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/magicreal.vae.safetensors","https://huggingface.co/doctord98/stable/resolve/main/vae.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Chilloutmix v2 (realistic)":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/chilloutmix-Ni.safetensors","https://huggingface.co/swl-models/chilloutmix-ni/resolve/main/chilloutmix-Ni.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Lyriel (semi realistic)":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/lyriel.safetensors","https://huggingface.co/serta21/lyriel_v16/resolve/main/lyriel_v16.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Dreamshaper (semi realistic)":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/dream.safetensors","https://huggingface.co/Lykon/DreamShaper/resolve/main/DreamShaper_7_pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Rev animated (2.5D)":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/rev.safetensors","https://huggingface.co/hanafuusen2001/ReVAnimated/resolve/main/revAnimated_v122.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Fentexi (2.5D)":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/fentexi.safetensors","https://huggingface.co/john1786/V08_V08/resolve/main/V08_V08.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Yabalmix (2.5D)":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/yabal25.safetensors","https://huggingface.co/doctord98/stable/resolve/main/yabalmix25.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/yabal25.vae.safetensors","https://huggingface.co/doctord98/stable/resolve/main/vae.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Camilia mix (anime)":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/camilia.safetensors","https://huggingface.co/Mods13/CamelliaMix/resolve/main/CamelliaMix_2.5D_V1.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/camilia.vae.safetensors","https://huggingface.co/doctord98/stable/resolve/main/vae.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Yabalmix v3 (anime)":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/yabal.safetensors","https://huggingface.co/doctord98/stable/resolve/main/yabalmix.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/yabal.vae.safetensors","https://huggingface.co/doctord98/stable/resolve/main/vae.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Manmaru mix (cartoon)":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/manmaru.safetensors","https://huggingface.co/doctord98/stable/resolve/main/manmarumix.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/manmaru.vae.safetensors","https://huggingface.co/doctord98/stable/resolve/main/vae.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Counterfeit v3 (anime)":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/counterfeit.safetensors","https://huggingface.co/gsdf/Counterfeit-V3.0/resolve/main/Counterfeit-V3.0.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/counterfeit.vae.safetensors","https://huggingface.co/doctord98/stable/resolve/main/vae.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Kyumix v1 (anime)":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/kyu.safetensors","https://huggingface.co/RuviKyu/Ruvi_Official_Models/resolve/main/KyuMix_v1.0.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Ruvimix v2 (anime)":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/ruvi.safetensors","https://huggingface.co/RuviKyu/Ruvi_Official_Models/resolve/main/RuviMix_v2.0.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Replicant v3 (anime)":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/replicant.safetensors","https://huggingface.co/gsdf/Replicant-V3.0/resolve/main/Replicant-V3.0_fp32.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Meinamix v10 (anime)":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/meina.safetensors","https://huggingface.co/Meina/MeinaMix/resolve/main/Meina%20V10%20-%20baked%20VAE.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Moyu (anime)":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/moyu.safetensors","https://huggingface.co/CasanovaSan/moyu/resolve/main/moyu.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/moyu.vae.safetensors","https://huggingface.co/doctord98/stable/resolve/main/vae.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Meinahentai v3 (anime)":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/meinahen.safetensors","https://huggingface.co/Meina/MeinaHentai/resolve/main/meinaHentai%20V3%20-%20baked%20VAE.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Meinapastal v5 (anime)":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/meinapas.safetensors","https://huggingface.co/Meina/MeinaPastel/resolve/main/MeinaPastelV5%20-%20Baked%20VAE.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "anylora (anime)":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/anylora.safetensors","https://civitai.com/api/download/models/95489"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/anylora.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Model-EX":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/modelEX.safetensors", "https://civitai.com/api/download/models/36396?type=Model&format=SafeTensor&size=full&fp=fp16"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/modelEX.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "JASMix 3.0 [Just Another Stylized Model]":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/jasmix.safetensors", "https://civitai.com/api/download/models/111548"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/jasmix.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "MiracleMix":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/miraclemix.safetensors", "https://civitai.com/api/download/models/108548"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/miraclemix.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "disneypixar":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/betterdisneypixar_bdpV10.safetensors", "https://civitai.com/api/download/models/106561"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/betterdisneypixar_bdpV10.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "disneypixar_Type A":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/disneyPixarCartoon_v10.safetensors", "https://civitai.com/api/download/models/69832"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/disneyPixarCartoon_v10.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "disneypixar_type B":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/disneyPixarCartoon_v10.safetensors", "https://civitai.com/api/download/models/80409"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/disneyPixarCartoon_v10.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "IdentityCrisis":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/identitycrisis.safetensors", "https://civitai.com/api/download/models/94798"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/identitycrisis.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "VinteProtogenMix":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/vinteprotogenmix.safetensors", "https://civitai.com/api/download/models/23690"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/vinteprotogenmix.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "Perfect World":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/perfectWorld.safetensors", "https://civitai.com/api/download/models/77276"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/perfectWorld.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "Remedy":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/remedy.safetensors", "https://civitai.com/api/download/models/92584"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/remedy.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "CompassionMix":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/compassionmix.safetensors", "https://civitai.com/api/download/models/92179"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/compassionmix.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "BokoMix":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/bokomix.safetensors", "https://civitai.com/api/download/models/93713"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/bokomix.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "DonutHoleMix":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/donutholemix.safetensors", "https://civitai.com/api/download/models/83231"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/donutholemix.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "Project KR4X - 2.5D / AaYMix":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/projectKR4X.safetensors", "https://civitai.com/api/download/models/79841"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/projectKR4X.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "Pastel-Mix [Stylized Anime Model]":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/pastelMixStylizedAnime_pastelMixPrunedFP16.safetensors", "https://civitai.com/api/download/models/6297"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/pastelMixStylizedAnime_pastelMixPrunedFP16.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "MeinaMix":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/meinamix_meinaV10.safetensors", "https://civitai.com/api/download/models/80511"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/meinamix_meinaV10.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "Anything V5":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/AnythingV5_v5PrtRE.safetensors", "https://civitai.com/api/download/models/33672?type=Model&format=PickleTensor&size=full&fp=fp16"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/AnythingV5_v5PrtRE.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "AbyssOrangeMix3":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/AbyssOrangeMix3.safetensors", "https://civitai.com/api/download/models/17233"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/AbyssOrangeMix3.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "DarkRevPikas":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/darkrevpikas.safetensors", "https://civitai.com/api/download/models/66374"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/darkrevpikas.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "OS-Ambrosia":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/osAmbrosia.safetensors", "https://civitai.com/api/download/models/82000"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/osAmbrosia.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "Epic Mix - V3":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/Epic_V3.safetensors", "https://civitai.com/api/download/models/79279"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/Epic_V3.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "MechaMix":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/MechaMix.safetensors", "https://civitai.com/api/download/models/74096"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/MechaMix.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "Ageless":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/ageless.safetensors", "https://civitai.com/api/download/models/74004"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/ageless.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "Mymix":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/mymix.safetensors", "https://civitai.com/api/download/models/75982"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/mymix.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "TMND-Mix":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/tmndMix_tmndMixIII.safetensors", "https://civitai.com/api/download/models/93612"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/tmndMix_tmndMixIII.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "dosmix":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/dosmix.safetensors", "https://huggingface.co/nolanaatama/dsmx/resolve/main/dsmx.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/dosmix.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "abstract anim spritesheets":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/abstractAnim_v1.ckpt", "https://civitai.com/api/download/models/1074"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/abstractAnim_v1.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "Corneros 7th Heaven Mix":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/corneos7thHeavenMix_v2.safetensors", "https://civitai.com/api/download/models/6878"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/corneos7thHeavenMix_v2.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "Identity Disorder":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/identityDisorderNSFW_20.safetensors", "https://civitai.com/api/download/models/61088"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/identityDisorderNSFW_20.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "Epic Mix":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/epicMixAnimeNSFW_v4UltimateAnime.safetensors", "https://civitai.com/api/download/models/34229"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/epicMixAnimeNSFW_v4UltimateAnime.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "MIXPROV4":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/Mixpro.safetensors", "https://huggingface.co/nolanaatama/mxprv4/resolve/main/mxprv4.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/Mixpro.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "Nyan mix":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/nyanMix_230303Absurd2.safetensors", "https://civitai.com/api/download/models/18151"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/nyanMix_230303Absurd2.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "viewer-mix_v1.7":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/viewerMixV17_viewerMixV17V2.safetensors", "https://civitai.com/api/download/models/25845"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/viewerMixV17_viewerMixV17V2.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "MoonTea":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/MoonTea_V2.0.safetensors", "https://huggingface.co/swl-models/MoonTea-v2/resolve/main/MoonTea_V2.0.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/MoonTea_V2.0.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "ToonYou":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/toonyou_beta1.safetensors", "https://civitai.com/api/download/models/58693"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/toonyou_beta1.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "CoffeeMix":
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/coffeemix_v20.safetensors", "https://civitai.com/api/download/models/53475"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/models/Stable-diffusion/coffeemix_v20.vae.safetensors", "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

  case "Sardonyx Redux":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/Sardonyx_Redux.safetensors","https://civitai.com/api/download/models/105566?type=Model&format=SafeTensor&size=pruned&fp=fp16"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/Sardonyx_Redux.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Ametrine REDUX":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/ametrineREDUX_v20.safetensors","https://huggingface.co/CasanovaSan/GalenaRedux/resolve/main/ametrineREDUX_v20.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/ametrineREDUX_v20.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Dark Sushi Mix":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/darkSushiMixMix_brighterPruned.safetensors","https://huggingface.co/CasanovaSan/GalenaRedux/resolve/main/darkSushiMixMix_brighterPruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/darkSushiMixMix_brighterPruned.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Galena Redux":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/galenaREDUX_v20.safetensors","https://huggingface.co/CasanovaSan/GalenaRedux/resolve/main/galenaREDUX_v20.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/galenaREDUX_v20.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "SCH Excelsior":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/schExcelsior_v20.safetensors","https://huggingface.co/CasanovaSan/GalenaRedux/resolve/main/schExcelsior_v20.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/schExcelsior_v20.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Hassaku Hentai":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/hassakuHentaiModel_v12.safetensors","https://huggingface.co/CasanovaSan/GalenaRedux/resolve/main/hassakuHentaiModel_v12.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/hassakuHentaiModel_v12.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "SakushiMix Hentai":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/sakushimixHentai_sakushiV20.safetensors","https://huggingface.co/CasanovaSan/GalenaRedux/resolve/main/sakushimixHentai_sakushiV20.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/sakushimixHentai_sakushiV20.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "RealCartoon3D":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/realcartoon_v4.safetensors","https://civitai.com/api/download/models/118590?type=Model&format=SafeTensor&size=full&fp=fp16"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "exquisiteDetails_v10":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/exquisiteDetails_v10.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/exquisiteDetails_v10.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/exquisiteDetails_v10.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "4cheemsblend_v10":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/4cheemsblend_v10.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/4cheemsblend_v10.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/4cheemsblend_v10.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Break domain anime":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/breakdomainanime_A0440.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/breakdomainanime_A0440.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/breakdomainanime_A0440.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Yabalmix v5":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/yabalMix_v5.safetensors","https://huggingface.co/CasanovaSan/models/resolve/main/yabalMix_v5.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/yabalMix_v5.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Sleeplessmix v1":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/sleeplessmix_v10.safetensors","https://huggingface.co/CasanovaSan/models/resolve/main/sleeplessmix_v10.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/sleeplessmix_v10.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "DarkrevPikas v3":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/darkrevpikas_v30Pruned.safetensors","https://huggingface.co/CasanovaSan/models/resolve/main/darkrevpikas_v30Pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/darkrevpikas_v30Pruned.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "ModelEX v2.5":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/modelEX_v25.safetensors","https://huggingface.co/CasanovaSan/models/resolve/main/modelEX_v25.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/modelEX_v25.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case"darkSushi RealP v9":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/darkSushi_realisticPussy_v9.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/darkSushi_realisticPussy_v9.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/darkSushi_realisticPussy_v9.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "AbyssOrange2xAnyv4":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/AbyssOrange2xAnyV4_HateMix_nsfw_ClipFix.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/AbyssOrange2xAnyV4_HateMix_nsfw_ClipFix.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/AbyssOrange2xAnyV4_HateMix_nsfw_ClipFix.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "end_v10":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/end_v10.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/end_v10.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/end_v10.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "envyoverdrivexl_v10DS":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/envyoverdrivexl_v10DS.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/envyoverdrivexl_v10DS.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/envyoverdrivexl_v10DS.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "nixesmix_v10":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/nixesmix_v10.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/nixesmix_v10.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/nixesmix_v10.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "toonyouJP_alpha1":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/toonyouJP_alpha1.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/toonyouJP_alpha1.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/toonyouJP_alpha1.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "blazingDrive_v03":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/blazingDrive_v03.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/blazingDrive_v03.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/blazingDrive_v03.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "camelliamix_v3":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/camelliamix_v3.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/camelliamix_v3.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/camelliamix_v3.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "darkSushiMixMix_colorful":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/darkSushiMixMix_colorful.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/darkSushiMixMix_colorful.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/darkSushiMixMix_colorful.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "darkSushi25D25D_v30":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/darkSushi25D25D_v30.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/darkSushi25D25D_v30.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/darkSushi25D25D_v30.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "darkSushiMixMix_darkerPruned":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/darkSushiMixMix_darkerPruned.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/darkSushiMixMix_darkerPruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/darkSushiMixMix_darkerPruned.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "duchaitenThiccboi_v10":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/duchaitenThiccboi_v10.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/duchaitenThiccboi_v10.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/duchaitenThiccboi_v10.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "kizukiAnimeHentai_animeHentaiV3":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/kizukiAnimeHentai_animeHentaiV3.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/kizukiAnimeHentai_animeHentaiV3.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/kizukiAnimeHentai_animeHentaiV3.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "nabimix_v2":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/nabimix_v2.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/nabimix_v2.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/nabimix_v2.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "orangeGalenyxMerge_v11":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/orangeGalenyxMerge_v11.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/orangeGalenyxMerge_v11.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/orangeGalenyxMerge_v11.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "renaigadeFantasy_v10":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/renaigadeFantasy_v10.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/renaigadeFantasy_v10.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/renaigadeFantasy_v10.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "ultraInfinityAnime_v2Yamime":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/ultraInfinityAnime_v2Yamime.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/ultraInfinityAnime_v2Yamime.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/ultraInfinityAnime_v2Yamime.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "yogirimix_v10":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/yogirimix_v10.safetensors","https://huggingface.co/CasanovaSan/SDFILES/resolve/main/yogirimix_v10.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/yogirimix_v10.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Lawlas's Yiffymix 2.0 (furry model)":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/Lawlas_Yiffymix_2.safetensors","https://civitai.com/api/download/models/15460?type=Model&format=SafeTensor&size=full&fp=fp16"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/Lawlas_Yiffymix_2.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "YiffyMix 3.2 (furry model)":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/YiffyMix_32.safetensors","https://civitai.com/api/download/models/127237?type=Model&format=SafeTensor&size=full&fp=fp32"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/YiffyMix_32.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

  case "Coconut furry mix (furry model)":
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/Coconut_furry_mix.safetensors","https://civitai.com/api/download/models/128393?type=Model&format=SafeTensor&size=full&fp=fp32"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
      subprocess.call(["curl","-Lo","/content/stable/models/Stable-diffusion/Coconut_furry_mix.vae.safetensors","https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

update_progress(20)
match Controlnet:
    case True:
        contrlnt = "/content/stable/extensions/contra"
        match os.path.exists(contrlnt):
          case False:
            subprocess.call(["git", "clone", "https://github.com/doctord98618/contra.git", "/content/stable/extensions/contra"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
            subprocess.call(["curl", "-Lo", "/content/stable/extensions/contra/models/control_v11p_sd15_canny.pth", "https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny.pth"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
            subprocess.call(["curl", "-Lo", "/content/stable/extensions/contra/models/control_v11f1p_sd15_depth.pth", "https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11f1p_sd15_depth.pth"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
            subprocess.call(["curl", "-Lo", "/content/stable/extensions/contra/models/control_v11p_sd15_openpose.pth", "https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose.pth"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
          case _:
              pass
    case _:
        pass
match Lora_pack:
  case True:
      lra = "/content/stable/models/LyCORIS"
      match os.path.exists(lra):
        case False:
          subprocess.call(["mkdir", "/content/stable/models/LyCORIS"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
          os.chdir("/content/stable/models/LyCORIS")
          subprocess.call(["curl", "-Lo", "/content/stable/models/LyCORIS/Lora.zip", "https://huggingface.co/SELEKCJONER/sdfiles/resolve/main/Lora.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
          subprocess.call(["unzip", "/content/stable/models/LyCORIS/Lora.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
          subprocess.call(["rm", "/content/stable/models/LyCORIS/Lora.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
          subprocess.call(["mkdir", "/content/stable/models/ESRGAN"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
          subprocess.call(["curl", "-Lo", "/content/stable/models/ESRGAN/ESRGAN.zip", "https://huggingface.co/nolanaatama/colab/resolve/main/upscalers.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
          os.chdir("/content/stable/models/ESRGAN")
          subprocess.call(["unzip", "/content/stable/models/ESRGAN/ESRGAN.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
          subprocess.call(["rm", "ESRGAN.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
          subprocess.call(["curl", "-Lo", "/content/stable/models/ESRGAN/4x_ArtStation1337_v2.pth", "https://huggingface.co/Duskfallcrew/my_merged_models/resolve/main/Upscaler_Backup/4x_ArtStation1337_v2.pth"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
          update_progress(50)
        case _:
             update_progress(50)
             pass
  case _:
      update_progress(50)
      pass

match Nuri_extensions:
    case True:
      #subprocess.call(["git", "clone", "https://github.com/nolanaatama/microsoftexcel-tunnels", "/content/stable/extensions/microsoftexcel-tunnels"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      #subprocess.call(["git", "clone", "https://github.com/hnmr293/posex", "/content/stable/extensions/posex"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      #subprocess.call(["git", "clone", "https://github.com/nolanaatama/a1111-microsoftexcel-tagcomplete", "/content/stable/extensions/a1111-microsoftexcel-tagcomplete"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      #subprocess.call(["git", "clone", "https://github.com/nolanaatama/microsoftexcel-supermerger", "/content/stable/extensions/microsoftexcel-supermerger"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      #subprocess.call(["git", "clone", "https://github.com/Coyote-A/ultimate-upscale-for-automatic1111", "/content/stable/extensions/ultimate-upscale-for-automatic1111"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      #subprocess.call(["git", "clone", "https://github.com/nolanaatama/a1111-microsoftexcel-locon", "/content/stable/extensions/a1111-microsoftexcel-locon"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      #subprocess.call(["git", "clone", "https://github.com/nolanaatama/microsoftexcel-3d-open-pose-editor", "/content/stable/extensions/microsoftexcel-3d-open-pose-editor"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      #subprocess.call(["git", "clone", "https://github.com/CiaraStrawberry/TemporalKit", "/content/stable/extensions/TemporalKit"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      #subprocess.call(["git", "clone", "https://github.com/nolanaatama/microsoftexcel-deforum", "/content/stable/extensions/microsoftexcel-deforum"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/embeddings.zip", "https://huggingface.co/nolanaatama/colab/resolve/main/embeddings.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      os.chdir("/content/stable/")
      update_progress(70)
      subprocess.call(["unzip", "/content/stable/embeddings.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      os.chdir("/content")
      #subprocess.call(["git", "clone", "https://github.com/Bing-su/adetailer", "/content/stable/extensions/adetailer"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/extensions/ext.zip", "https://huggingface.co/SELEKCJONER/sdfiles/resolve/main/ext1.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["curl", "-Lo", "/content/stable/extensions/aspectratiohelper.zip", "https://huggingface.co/NuriDerBurrito/Burritoext/resolve/main/aspectratiohelper.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      #subprocess.call(["curl", "-Lo", "/content/stable/extensions/canvaszoom.zip", "https://huggingface.co/NuriDerBurrito/Burritoext/resolve/main/canvaszoom.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      #subprocess.call(["curl", "-Lo", "/content/stable/extensions/inpainganythingo.zip", "https://huggingface.co/NuriDerBurrito/Burritoext/resolve/main/inpainganythingo.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      #subprocess.call(["curl", "-Lo", "/content/stable/extensions/Roopie.zip", "https://huggingface.co/NuriDerBurrito/Burritoext/resolve/main/Roopie.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      os.chdir("/content/stable/extensions")
      subprocess.call(["unzip", "/content/stable/extensions/ext.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      subprocess.call(["unzip", "/content/stable/extensions/aspectratiohelper.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      #subprocess.call(["unzip", "/content/stable/extensions/canvaszoom.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      #subprocess.call(["unzip", "/content/stable/extensions/inpainganythingo.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      #subprocess.call(["unzip", "/content/stable/extensions/Roopie.zip"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
      os.chdir("/content")
      update_progress(70)
    case _:
        update_progress(70)
        pass
match Nuri_embeddings:
  case True:
    subprocess.call(["curl", "-Lo", "/content/stable/embeddings/style-swirlmagic.pt", "https://civitai.com/api/download/models/30926"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
    subprocess.call(["curl", "-Lo", "/content/stable/embeddings/Mangastyle.pt", "https://civitai.com/api/download/models/84156"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
    subprocess.call(["curl", "-Lo", "/content/stable/embeddings/Fixhand.pt", "https://civitai.com/api/download/models/111363"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
    subprocess.call(["curl", "-Lo", "/content/stable/embeddings/PunchIt_NegV1.pt", "https://civitai.com/api/download/models/111411"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
    update_progress(90)
  case _:
      update_progress(95)
      pass
os.chdir('/content/stable')
#!git clone https://huggingface.co/doctord98/embeddings
#match Custom_css:
#  case True:
#    subprocess.call(["rm", "/stable/style.css"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
#    subprocess.call(["curl", "-Lo", "/content/stable/style.css", "https://huggingface.co/SELEKCJONER/sdfiles/resolve/main/style.css"], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
#  case _:
#    pass

match Autostart:
    case True:
        try:
            update_progress(100)
            while True:
                html_end = """
<script>
document.getElementById('elevator_music').pause();
document.getElementById("bouncing_image").remove();
document.getElementById("progress-bar").remove();
</script>
"""
                display(HTML(html_end))
                html_str = f"""
<audio id="elevator_music" src="https://henk.tech/colabkobold/silence.m4a" autoplay loop style="display:none">
</audio>
"""

                display(HTML(html_str))
                # !COMMANDLINE_ARGS="--share --xformers --no-half-vae --disable-safe-unpickle --enable-insecure-extension-access" REQS_FILE="requirements.txt" python launch.py
        except KeyboardInterrupt:
            try:
                while True:
                    # !COMMANDLINE_ARGS="--share --xformers --no-half-vae --disable-safe-unpickle --enable-insecure-extension-access" REQS_FILE="requirements.txt" python launch.py
            except KeyboardInterrupt:
                pass
    case _:
        update_progress(100)
        pass
html_end = """
<script>
document.getElementById('elevator_music').pause();
document.getElementById("bouncing_image").remove();
document.getElementById("progress-bar").remove();
</script>
"""
display(HTML(html_end))
html_str = f"""
<audio id="elevator_music" src="https://henk.tech/colabkobold/silence.m4a" autoplay loop style="display:none">
</audio>
"""

display(HTML(html_str))

print('done, you can download more models or launch below')
